# %%
# Definition for singly-linked list.  35s
class ListNode(object):
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution(object):
    def reverseBetween(self, head, m, n):
        """
        :type head: ListNode
        :type m: int
        :type n: int
        :rtype: ListNode
        """
        if not head or not head.next or m >= n:
            return head
        
        p = ListNode(0); p.next = head
        p0, q, p1, p2 = p, p, p, p
        for i in range(n):
            if q.next: q = q.next
            else: return head
            if i == m-1: p1 = q
            if i == n-1: p2 = q
            if i < m-1: p = p.next
        
        q1 = p1.next
        p1.next = p2.next
        for i in range(n-m-1):
            q2 = q1.next
            q1.next = p1
            p1 = q1
            q1 = q2
            
        q1.next = p1
        p.next = q1
        return p0.next

    def printf(self, head):
        p = head
        while p:
            if p.next == None:
                print(p.val)
            else:
                print(p.val, end=" ")
            p = p.next

head = ListNode(1);
p = head;
p.next = ListNode(2);p = p.next
p.next = ListNode(3);p = p.next
p.next = ListNode(4);p = p.next
p.next = ListNode(5);p = p.next
# p.next = ListNode(6);p = p.next
# p.next = ListNode(1);p = p.next;

Solution().printf(head)
head = Solution().reverseBetween(head, 2, 4)
Solution().printf(head)
# Out:
# 1 2 3 4 5
# 1 4 3 2 5

# %%
# Definition for singly-linked list.  32s
# class ListNode(object):
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution(object):
    def reverseBetween(self, head, m, n):
        """
        :type head: ListNode
        :type m: int
        :type n: int
        :rtype: ListNode
        """
        
        if m == n:
            return head
        
        i = 1
        dummy = ListNode(0)
        dummy.next = head
        pre = dummy
        
        while i < m:
            i += 1
            pre = pre.next
            
        cur = pre.next
        tail = None
        while i <= n:
            i += 1
            tmp = cur.next
            cur.next = tail
            tail = cur
            cur = tmp
         
        pre.next.next = cur
        pre.next = tail
            
        return dummy.next

# %%
# Definition for singly-linked list.  26s
# class ListNode(object):
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution(object):
    def reverseBetween(self, head, m, n):
        """
        :type head: ListNode
        :type m: int
        :type n: int
        :rtype: ListNode
        """
        if head is None or head.next is None:
            return head
        dummy = ListNode(0)
        dummy.next = head
        first, start = None, dummy
        for i in range(m):
            first = start
            start = start.next
        prev = None
        last = start
        for i in range(n-m+1):
            next = start.next
            start.next = prev
            prev = start
            start = next
        last.next = start
        first.next = prev
        return dummy.next
